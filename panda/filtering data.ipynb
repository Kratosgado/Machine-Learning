# %%
import pandas as pd

data = pd.read_csv('../airport-frequencies.csv')

# %%
data.head()
# Out:
#        id  airport_ref airport_ident   type          description  \
# 0   70518         6528          00CA   CTAF                 CTAF
# 1  307581         6589          01FL  ARCAL                  NaN
# 2   75239         6589          01FL   CTAF  CEDAR KNOLL TRAFFIC
# 3   60191         6756          04CA   CTAF                 CTAF
# 4   59287         6779          04MS   UNIC               UNICOM
#
#    frequency_mhz
# 0          122.9
# 1          122.9
# 2          122.8
# 3          122.9
# 4          122.8

# %%
highest_aiiport_ref = (data['airport_ref'] > 6500)

# %%
highest_aiiport_ref
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 28922    True
# 28923    True
# 28924    True
# 28925    True
# 28926    True
# Name: airport_ref, Length: 28927, dtype: bool

# %%
data.loc[highest_aiiport_ref]
# Out:
#            id  airport_ref airport_ident   type          description  \
# 0       70518         6528          00CA   CTAF                 CTAF
# 1      307581         6589          01FL  ARCAL                  NaN
# 2       75239         6589          01FL   CTAF  CEDAR KNOLL TRAFFIC
# 3       60191         6756          04CA   CTAF                 CTAF
# 4       59287         6779          04MS   UNIC               UNICOM
# ...       ...          ...           ...    ...                  ...
# 28922   51247        27242          ZYTL   ATIS                 ATIS
# 28923   51248        27242          ZYTL    TWR           DALIAN TWR
# 28924   51243        27243          ZYTX   ATIS                 ATIS
# 28925   51244        27243          ZYTX    TWR         SHENYANG TWR
# 28926   51190        27244          ZYYJ    TWR                  TWR
#
#        frequency_mhz
# 0             122.90
# 1             122.90
# 2             122.80
# 3             122.90
# 4             122.80
# ...

# %%
data.loc[highest_aiiport_ref, ['type', 'description', 'frequency_mhz']]
# Out:
#         type          description  frequency_mhz
# 0       CTAF                 CTAF         122.90
# 1      ARCAL                  NaN         122.90
# 2       CTAF  CEDAR KNOLL TRAFFIC         122.80
# 3       CTAF                 CTAF         122.90
# 4       UNIC               UNICOM         122.80
# ...      ...                  ...            ...
# 28922   ATIS                 ATIS         126.65
# 28923    TWR           DALIAN TWR         118.25
# 28924   ATIS                 ATIS         127.45
# 28925    TWR         SHENYANG TWR         118.10
# 28926    TWR                  TWR         130.00
#
# [15064 rows x 3 columns]

# %%
data['type'].unique()
# Out:
# array(['CTAF', 'ARCAL', 'UNIC', 'APP', 'GND', 'TWR', 'CNTR', 'ARTC',
#        'MISC', 'A/D', 'MULT', 'A/G', 'ATIS', 'INFO', 'OPS', 'PMSV',
#        'APP/DEP', 'AWOS', 'UNICOM', 'FSS', 'RDO', 'CLD',
#        'Woodlands Adviso', 'AFIS', 'COM', 'Non controlled', 'ctaf', 'FIA',
#        'Ciljuge Info', 'HIS', 'ATS', 'ACC', 'RDR', 'DEP', 'afis',
#        'TWR: BIRK', 'TRFC', 'RMP', 'MF', 'ATF', 'VFR Advisory', 'CPR1',
#        'Ground', 'AAS', 'RCO', 'CTAF(R)', 'Departures', 'Ctaf', 'MIL',
#        'ARR/DEP', 'CLNC DEL', 'tfc', 'UNICOM ltd hrs O', 'TOWER', 'TFC',
#        'TCA', 'ASOS', 'Unicom', 'Ambulance Dispat', 'Advisory', 'Gliding',
#        'Vhf', 'ARR', 'RADIO', 'PAL', 'VDF', 'APRON ADV', 'INTL AIR',
#        'PVT ADV', 'EMR', 'TML', 'LWIS', 'MF/RDO', 'RCO. Bcst', 'APRON',
#        'VFR ADV', 'APRT RDO', 'FBO', 'PAD', 'info', 'Info', 'Dolmar INFO',
#        'Gössenheim INFO', 'DIR', '131.7', 'SAB - VOR', 'ENG VOR',
# ...

# %%
types = ['AWOS', 'UNICOM', 'FSS', 'RDO', 'CLD']

# %%
filt = data['type'].isin(types)

# %%
data.loc[filt]
# Out:
#            id  airport_ref airport_ident    type        description  \
# 97      71572        10265          38AZ    AWOS             AWOS 2
# 103    333773        10702          3OH0  UNICOM                NaN
# 114     66205        11355          4AZ7     FSS       PRESCOTT RDO
# 117     60226        20622          4PA0     RDO   WILLIAMSPORT RDO
# 119     61753        11711          4TA0     FSS  MONTGOMERY CO RDO
# ...       ...          ...           ...     ...                ...
# 28823   55293        27209          ZMDZ     RDO         HONGOR RDO
# 28825   55289        27210          ZMKD     RDO        KHAR US RDO
# 28828   55287        27211          ZMMN     RDO                RDO
# 28870   51181        27223          ZSPD     CLD                DEL
# 28885   51233        27225          ZSSS     CLD           DELIVERY
#
#        frequency_mhz
# 97           119.225
# 103          122.900
# 114          122.300
# 117          114.600
# 119          122.200
# ...
